# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sympy.abc import y
from sympy.abc import x
import sympy as sp
from sympy import S

# %%
x= sp.symbols('x')
g = input("")
sp.plot(g)
# Out:
# sin(x)
